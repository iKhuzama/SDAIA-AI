# %% [markdown]
# # Traffic Light Counting

# %% [markdown]
# ## Setup Environment

# %% [markdown]
# Before you begin, ensure you have the necessary libraries installed. You will need `opencv`, and `ultralytics` among others.
# If these are not installed, you should install them.

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.1/872.1 kB 52.4 MB/s eta 0:00:00

# %%
import cv2
from ultralytics import YOLO, solutions
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Load the YOLO Model

# %% [markdown]
# You will first need to load the YOLO model, there is a custom model for this exam called `YOLO_Model.pt` under Datasets file ⚠️ PLEASE USE THIS MODEL AND DO NOT USE ANY OTHER MODEL ⚠️.
# Write the code to load the YOLO model below:

# %%
model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 342MB/s]

# %% [markdown]
# ## Prepare the Video Capture

# %% [markdown]
# Create a variable to capture the video frames, you can use `cv2.VideoCapture()` to achive this.

# %%
cap = cv2.VideoCapture('/content/Traffic_light.mp4')
assert cap.isOpened(), 'The file dose not Found'

# %% [markdown]
# ## Get Video Information

# %% [markdown]
# You can use `cv2` library to get these information fro the `VideoCapture()` variable you created to extract these information:
# * `height`: Video's height.
# * `width`: Video's width.
# * `fps`: Video's frames.

# %%
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT,  cv2.CAP_PROP_FPS))

# %% [markdown]
# ## Prepare Video Writer to Store the Output

# %% [markdown]
# Create a variable that uses `cv2.VideoCapture()` to save the video with the bounding boxes, specified Region of Interest rectangle (ROI) and the counted vehicles on each sides. You will need to make the video with the same `fps`, `width`, `height`, and specify the codec and output path of the video.

# %%
# Define region points
region_points = [
        (219, 201), # Top-left
        (49, 319),  # Top-right
        (527, 409),  # Bottom-right
        (687, 237)  # Bottom-left
        ]

# Video writer
video_writer = cv2.VideoWriter("Traffic.mp4", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init Object Counter
counter = solutions.ObjectCounter(
    view_img=True,
    reg_pts=region_points,
    names=model.names,
    draw_tracks=True,
    count_reg_color=(255, 0, 0),
    line_thickness=1,
    view_out_counts = False
)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Polygon Counter Initiated.

# %% [markdown]
# ## Process Video Frames and Identify Vehicles

# %%
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False, classes=2)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Collecting lapx>=0.5.2
#   Downloading lapx-0.5.10.post1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from lapx>=0.5.2) (1.26.4)
# Downloading lapx-0.5.10.post1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 139.8 MB/s eta 0:00:00
# Installing collected packages: lapx
# Successfully installed lapx-0.5.10.post1
#
# requirements: AutoUpdate success ✅ 2.4s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 352x640 9 cars, 116.5ms
# Speed: 18.2ms preprocess, 116.5ms inference, 937.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.1ms
# Speed: 3.9ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.9ms
# Speed: 4.0ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.0ms
# Speed: 4.1ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.1ms
# Speed: 3.4ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.2ms
# Speed: 2.8ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.1ms
# Speed: 3.2ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.5ms
# Speed: 2.9ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.8ms
# Speed: 3.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.5ms
# Speed: 3.2ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.6ms
# Speed: 2.5ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 11.1ms
# Speed: 3.1ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 12.0ms
# Speed: 3.9ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 8.0ms
# Speed: 4.2ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.3ms
# Speed: 4.0ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.6ms
# Speed: 2.9ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 8.7ms
# Speed: 2.6ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 12.1ms
# Speed: 4.4ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.5ms
# Speed: 2.8ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.0ms
# Speed: 3.4ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.4ms
# Speed: 3.0ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.8ms
# Speed: 3.0ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 11.9ms
# Speed: 2.8ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 8.4ms
# Speed: 3.4ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.6ms
# Speed: 2.9ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 3.2ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.3ms
# Speed: 2.8ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.3ms
# Speed: 4.0ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.4ms
# Speed: 4.0ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 3.1ms preprocess, 7.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 6.8ms
# Speed: 4.0ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 3.1ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.5ms
# Speed: 3.3ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 3.5ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.3ms
# Speed: 3.3ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.6ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 2.8ms preprocess, 7.3ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.1ms
# Speed: 4.2ms preprocess, 8.1ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 3.7ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 7.4ms
# Speed: 2.7ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.9ms
# Speed: 2.6ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.4ms
# Speed: 3.4ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.8ms
# Speed: 3.3ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 3.3ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 3.3ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.1ms
# Speed: 3.4ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.3ms
# Speed: 2.9ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.3ms
# Speed: 2.9ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.6ms
# Speed: 2.9ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.7ms
# Speed: 4.5ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.7ms
# Speed: 4.1ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 3.5ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 3.5ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.8ms
# Speed: 4.0ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 10.6ms
# Speed: 3.8ms preprocess, 10.6ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 9.4ms
# Speed: 7.3ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 7.2ms
# Speed: 2.6ms preprocess, 7.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 6.9ms
# Speed: 3.2ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 7.5ms
# Speed: 2.9ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 11.3ms
# Speed: 3.6ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 12.2ms
# Speed: 2.6ms preprocess, 12.2ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.0ms
# Speed: 4.5ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.9ms
# Speed: 4.7ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.2ms
# Speed: 4.4ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 7.0ms
# Speed: 3.4ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 16.7ms
# Speed: 4.4ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.7ms
# Speed: 2.6ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.2ms
# Speed: 3.2ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.2ms
# Speed: 4.8ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.2ms
# Speed: 4.4ms preprocess, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.1ms
# Speed: 2.8ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.9ms
# Speed: 2.7ms preprocess, 12.9ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.7ms
# Speed: 2.5ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.3ms
# Speed: 2.6ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.8ms
# Speed: 3.7ms preprocess, 13.8ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 7.9ms
# Speed: 3.1ms preprocess, 7.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 8.4ms
# Speed: 3.4ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 9.0ms
# Speed: 4.6ms preprocess, 9.0ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 17.7ms
# Speed: 2.8ms preprocess, 17.7ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.9ms
# Speed: 4.2ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.9ms
# Speed: 4.8ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.6ms
# Speed: 4.1ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.8ms
# Speed: 2.7ms preprocess, 15.8ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.1ms
# Speed: 3.2ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 16.4ms
# Speed: 2.5ms preprocess, 16.4ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 15.6ms
# Speed: 4.3ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 14.0ms
# Speed: 3.8ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.6ms
# Speed: 2.7ms preprocess, 13.6ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 17.1ms
# Speed: 2.6ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.2ms
# Speed: 4.8ms preprocess, 12.2ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.9ms
# Speed: 2.9ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.4ms
# Speed: 2.7ms preprocess, 15.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.7ms
# Speed: 2.7ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.6ms
# Speed: 3.7ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.5ms
# Speed: 2.7ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.6ms
# Speed: 2.7ms preprocess, 12.6ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.8ms
# Speed: 2.6ms preprocess, 12.8ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.3ms
# Speed: 2.8ms preprocess, 13.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.0ms
# Speed: 6.4ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.0ms
# Speed: 2.7ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.3ms
# Speed: 2.4ms preprocess, 12.3ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.6ms
# Speed: 4.0ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.9ms
# Speed: 2.8ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.4ms
# Speed: 2.7ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 16.6ms
# Speed: 3.7ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 17.2ms
# Speed: 2.5ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 14.2ms
# Speed: 3.2ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 17.2ms
# Speed: 2.5ms preprocess, 17.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.6ms
# Speed: 5.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 16.5ms
# Speed: 3.1ms preprocess, 16.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 17.6ms
# Speed: 2.8ms preprocess, 17.6ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.7ms
# Speed: 2.7ms preprocess, 13.7ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.5ms
# Speed: 2.6ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.6ms
# Speed: 2.8ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.3ms
# Speed: 2.7ms preprocess, 12.3ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.0ms
# Speed: 2.6ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.0ms
# Speed: 2.4ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 15.4ms
# Speed: 2.8ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 15.9ms
# Speed: 2.6ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 15.2ms
# Speed: 2.8ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 14.3ms
# Speed: 2.8ms preprocess, 14.3ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.8ms
# Speed: 4.1ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.6ms
# Speed: 3.5ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.8ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.9ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 5.2ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.1ms
# Speed: 3.1ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.9ms
# Speed: 4.3ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.2ms
# Speed: 4.2ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.9ms
# Speed: 3.3ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 6.9ms
# Speed: 3.2ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 3.0ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 2.8ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 3.6ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 3.1ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.1ms
# Speed: 3.1ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.3ms
# Speed: 3.2ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.5ms
# Speed: 3.9ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.7ms
# Speed: 2.7ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 6.9ms
# Speed: 3.5ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.8ms
# Speed: 2.8ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.4ms
# Speed: 2.5ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.7ms
# Speed: 3.3ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 14.7ms
# Speed: 2.5ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 4.6ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.8ms
# Speed: 2.5ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.3ms
# Speed: 4.8ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.5ms
# Speed: 2.6ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.3ms
# Speed: 3.5ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.5ms
# Speed: 4.2ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 4.2ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 2.8ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.7ms
# Speed: 2.5ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.1ms
# Speed: 3.0ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.3ms
# Speed: 5.2ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.8ms
# Speed: 3.3ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 14.0ms
# Speed: 2.9ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.5ms
# Speed: 4.2ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 3.7ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.1ms
# Speed: 3.6ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.7ms
# Speed: 2.7ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.3ms
# Speed: 4.7ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.2ms
# Speed: 2.8ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.2ms
# Speed: 3.3ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 8.3ms
# ...
#
# 0: 352x640 15 cars, 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 15.2ms
# Speed: 4.9ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 14.3ms
# Speed: 3.1ms preprocess, 14.3ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.8ms
# Speed: 2.5ms preprocess, 12.8ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.6ms
# Speed: 2.5ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.5ms
# Speed: 3.2ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.6ms
# Speed: 3.6ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.7ms
# Speed: 3.5ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 15.9ms
# Speed: 3.7ms preprocess, 15.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.1ms
# Speed: 3.7ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 13.1ms
# Speed: 3.1ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.3ms
# Speed: 2.6ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.1ms
# Speed: 2.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.6ms
# Speed: 3.3ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 13.6ms
# Speed: 2.7ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.9ms
# Speed: 2.5ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.4ms
# Speed: 2.9ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.5ms
# Speed: 4.2ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.6ms
# Speed: 5.1ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.6ms
# Speed: 3.3ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.9ms
# Speed: 3.6ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.9ms
# Speed: 3.0ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.1ms
# Speed: 4.6ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.4ms
# Speed: 2.6ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.0ms
# Speed: 2.7ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.1ms
# Speed: 3.4ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.0ms
# Speed: 2.4ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.7ms
# Speed: 2.5ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 15.6ms
# Speed: 2.5ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.9ms
# Speed: 3.0ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.8ms
# Speed: 3.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.8ms
# Speed: 3.1ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.3ms
# Speed: 2.4ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.0ms
# Speed: 5.2ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 14.2ms
# Speed: 2.8ms preprocess, 14.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.1ms
# Speed: 4.3ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.9ms
# Speed: 2.9ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 14.6ms
# Speed: 3.2ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.7ms
# Speed: 3.6ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.8ms
# Speed: 3.3ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.4ms
# Speed: 2.4ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.4ms
# Speed: 3.8ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.4ms
# Speed: 2.8ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.2ms
# Speed: 3.3ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.2ms
# Speed: 4.5ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.9ms
# Speed: 4.0ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.4ms
# Speed: 2.5ms preprocess, 12.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.5ms
# Speed: 2.6ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.0ms
# Speed: 5.3ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.3ms
# Speed: 3.0ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.9ms
# Speed: 3.4ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.8ms
# Speed: 2.9ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 8.3ms
# Speed: 3.3ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 7.2ms
# Speed: 4.7ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 9.8ms
# Speed: 4.4ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 12.1ms
# Speed: 2.7ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.5ms
# Speed: 2.4ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 cars, 11.8ms
# Speed: 2.6ms preprocess, 11.8ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
# Resorcess
# https://docs.ultralytics.com/guides/object-counting/#real-world-applications
# https://roboflow.github.io/polygonzone/

# %% [markdown]
# ## Save and Submit Your Work

# %% [markdown]
# Submit both the notebook and the output video
