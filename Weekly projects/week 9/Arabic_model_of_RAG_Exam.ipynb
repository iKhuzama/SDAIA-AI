# %% [markdown]
# # Traffic Violation RAG System
# In this exam, you will implement a Retrieval-Augmented Generation (RAG) system that uses a language model and a vector database to answer questions about traffic violations. The goal is to generate answers with relevant data based on a dataset of traffic violations and fines.
#
# Here are helpful resources:
# * [LangChain](https://www.langchain.com/)
# * [groq cloud documentation](https://console.groq.com/docs/models)
# * [LangChain HuggingFace](https://python.langchain.com/docs/integrations/text_embedding/sentence_transformers/)
# * [Chroma Vector Store](https://python.langchain.com/docs/integrations/vectorstores/chroma/)
# * [Chroma Website](https://docs.trychroma.com/getting-started)
# * [ChatGroq LangChain](https://python.langchain.com/docs/integrations/chat/groq/)
# * [LLM Chain](https://api.python.langchain.com/en/latest/chains/langchain.chains.llm.LLMChain.html#langchain.chains.llm.LLMChain)
#
# Dataset [source](https://www.moi.gov.sa/wps/portal/Home/sectors/publicsecurity/traffic/contents/!ut/p/z0/04_Sj9CPykssy0xPLMnMz0vMAfIjo8ziDTxNTDwMTYy83V0CTQ0cA71d_T1djI0MXA30gxOL9L30o_ArApqSmVVYGOWoH5Wcn1eSWlGiH1FSlJiWlpmsagBlKCQWqRrkJmbmqRqUZebngB2gUJAKdERJZmqxfkG2ezgAhzhSyw!!/)
#
# Some installs if needed:
# ```python
# !pip install langchain_huggingface langchain langchain-community langchain_chroma Chroma langchain_groq LLMChain
# ```

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_core-0.3.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.123-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Downloading langchain-0.3.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.4 MB/s eta 0:00:00
# Downloading langchain_core-0.3.1-py3-none-any.whl (405 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 24.3 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.123-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 kB 18.2 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.2 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.4 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: orjson, jsonpointer, h11, jsonpatch, httpcore, httpx, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.0 langchain-core-0.3.1 langchain-text-splitters-0.3.0 langsmith-0.1.123 orjson-3.10.7

# %%
# !pip install langchain_huggingface langchain-community langchain_chroma Chroma langchain_groq
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-0.1.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting langchain_chroma
#   Downloading langchain_chroma-0.1.4-py3-none-any.whl.metadata (1.6 kB)
# Collecting Chroma
#   Downloading Chroma-0.2.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting langchain_groq
#   Downloading langchain_groq-0.2.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.23.5)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.3.1)
# Collecting sentence-transformers>=2.6.0 (from langchain_huggingface)
#   Downloading sentence_transformers-3.1.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (4.42.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.123)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.25.2)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Collecting chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 (from langchain_chroma)
#   Downloading chromadb-0.5.7-py3-none-any.whl.metadata (6.8 kB)
# Collecting fastapi<1,>=0.95.2 (from langchain_chroma)
#   Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting groq<1,>=0.4.1 (from langchain_groq)
#   Downloading groq-0.11.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.2.1)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.8.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading posthog-3.6.6-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pypika>=0.48.9 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.66.4)
# Collecting overrides>=7.3.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.12.3)
# Collecting kubernetes>=28.1.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading mmh3-5.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (13.7.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi<1,>=0.95.2->langchain_chroma)
#   Downloading starlette-0.38.5-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.1)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.0->langchain-community) (0.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_huggingface) (1.33)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.7.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.3.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (9.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (0.4.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (1.2.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.0.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain_huggingface) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.2.2)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.13.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (8.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.63.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (71.0.4)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.5.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.1.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.6.0)
# Downloading langchain_huggingface-0.1.0-py3-none-any.whl (20 kB)
# Downloading langchain_community-0.3.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 78.4 MB/s eta 0:00:00
# Downloading langchain_chroma-0.1.4-py3-none-any.whl (10 kB)
# Downloading langchain_groq-0.2.0-py3-none-any.whl (14 kB)
# Downloading chromadb-0.5.7-py3-none-any.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.2/599.2 kB 42.1 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 79.5 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fastapi-0.115.0-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 9.2 MB/s eta 0:00:00
# Downloading groq-0.11.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 9.8 MB/s eta 0:00:00
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading sentence_transformers-3.1.0-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 21.7 MB/s eta 0:00:00
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 23.6 MB/s eta 0:00:00
# Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 72.1 MB/s eta 0:00:00
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.5 MB/s eta 0:00:00
# Downloading mmh3-5.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 8.7 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 96.8 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 5.9 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.6 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 13.8 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.9 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.6.6-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 4.6 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.38.5-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 5.8 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.3 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 23.5 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 73.0 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 30.7 MB/s eta 0:00:00
# Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 15.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 43.0 MB/s eta 0:00:00
# Building wheels for collected packages: Chroma, pypika
#   Building wheel for Chroma (setup.py) ... done
#   Created wheel for Chroma: filename=Chroma-0.2.0-py3-none-any.whl size=7095 sha256=08a28fa29984d44a1d2fa433b364721eeafe1495a97988cf5b2363f20d0f13f4
#   Stored in directory: /root/.cache/pip/wheels/58/74/75/a6ab7999ae473ecbe819bc5cae9ccb902429dd6c60795f5112
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=6de3fc9b4411cc96a6b71426def38ee27cb87d6cd3a461cac7e94f2a7fa63077
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built Chroma pypika
# Installing collected packages: pypika, monotonic, Chroma, websockets, uvloop, uvicorn, python-dotenv, overrides, opentelemetry-util-http, opentelemetry-proto, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, mmh3, marshmallow, humanfriendly, httptools, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, typing-inspect, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, pydantic-settings, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, nvidia-cusolver-cu12, kubernetes, groq, fastapi, dataclasses-json, opentelemetry-sdk, opentelemetry-instrumentation-asgi, sentence-transformers, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain_groq, langchain_huggingface, chromadb, langchain-community, langchain_chroma
# Successfully installed Chroma-0.2.0 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 chroma-hnswlib-0.7.6 chromadb-0.5.7 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.14 fastapi-0.115.0 groq-0.11.0 httptools-0.6.1 humanfriendly-10.0 kubernetes-30.1.0 langchain-community-0.3.0 langchain_chroma-0.1.4 langchain_groq-0.2.0 langchain_huggingface-0.1.0 marshmallow-3.22.0 mmh3-5.0.0 monotonic-1.6 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 overrides-7.7.0 posthog-3.6.6 pydantic-settings-2.5.2 pypika-0.48.9 python-dotenv-1.0.1 sentence-transformers-3.1.0 starlette-0.38.5 typing-inspect-0.9.0 uvicorn-0.30.6 uvloop-0.20.0 watchfiles-0.24.0 websockets-13.0.1

# %%
# !kaggle datasets download -d khaledzsa/dataset
# !unzip dataset.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.17 / client 1.6.14)
# Dataset URL: https://www.kaggle.com/datasets/khaledzsa/dataset
# License(s): unknown
# Downloading dataset.zip to /content
#   0% 0.00/3.73k [00:00<?, ?B/s]
# 100% 3.73k/3.73k [00:00<00:00, 8.93MB/s]
# Archive:  dataset.zip
#   inflating: Dataset.csv

# %% [markdown]
# ## Step 1: Install Required Libraries

# %% [markdown]
# To begin, install the necessary libraries for this project. The libraries include `LangChain` for building language model chains, and `Chroma` for managing a vector database.

# %%
# !pip install langchain_huggingface langchain langchain-community langchain_chroma Chroma langchain_groq LLMChain
# Out:
# Requirement already satisfied: langchain_huggingface in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: langchain_chroma in /usr/local/lib/python3.10/dist-packages (0.1.4)
# Requirement already satisfied: Chroma in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: langchain_groq in /usr/local/lib/python3.10/dist-packages (0.2.0)
# ERROR: Could not find a version that satisfies the requirement LLMChain (from versions: none)
# ERROR: No matching distribution found for LLMChain

# %% [markdown]
# # Step 2: Load the Traffic Violations Dataset

# %% [markdown]
# You are provided with a dataset of traffic violations. Load the CSV file into a pandas DataFrame and preview the first few rows of the dataset using `.head()`. You can also try and see the dataset's characteristics.

# %%
import os
import pandas as pd
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)
import markdown
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain import LLMChain
from langchain.prompts import PromptTemplate
from langchain.vectorstores import Chroma
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain_groq import ChatGroq
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
df= pd.read_csv('/content/Dataset.csv')
df
# Out:
#                                               المخالفة  \
# 0    قيادة المركبة في الأسواق التي لا يسمح بالقيادة...
# 1     ترك المركبة مفتوحة وفي وضع التشغيل بعد مغادرتها.
# 2                         عدم وجود تأمين ساري للمركبة.
# 3        عبور المشاة للطرق من غير الأماكن المخصصة لهم.
# 4                عدم تقيد المشاة بالإشارات الخاصة بهم.
# ..                                                 ...
# 99   القيام بأعمال الطرق قبل التنسيق مع الإدارة الم...
# 100  سماح أصحاب الحيوانات بعبور حيواناتهم من غير ال...
# 101                   استخدام لوحات غير عائدة للمركبة.
# 102               طمس رقم هيكل المركبة أو محاولة طمسه.
# 103      المجازفة بعبور الأودية والشعاب أثناء جريانها.
#
#                                الغرامة
# 0       الغرامة المالية 100 - 150 ريال
# 1       الغرامة المالية 100 - 150 ريال
# 2       الغرامة المالية 100 - 150 ريال
# 3       الغرامة المالية 100 - 150 ريال
# 4       الغرامة المالية 100 - 150 ريال
# ..                                 ...
# 99   الغرامة المالية 5000 - 10000 ريال
# 100  الغرامة المالية 5000 - 10000 ريال
# 101  الغرامة المالية 5000 - 10000 ريال
# 102  الغرامة المالية 5000 - 10000 ريال
# 103  الغرامة المالية 5000 - 10000 ريال
#
# [104 rows x 2 columns]

# %% [markdown]
# ## Step 3: Create Markdown Content from the Dataset

# %% [markdown]
# For each traffic violation in the dataset, you will generate markdown text that describes the violation and the associated fine. Create a loop to iterate through the dataset and store the generated markdown in a list. Each fine should look like this:
#
# **المخالفة** - الغرامة

# %%
directory = 'data/markdown_files'
os.makedirs(directory, exist_ok=True)

# %%
for i in range(0, 104):

    title = df['الغرامة'].iloc[i]
    content = df['المخالفة'].iloc[i]

    markdown_content = f"# {title}\n\n"
    markdown_content += f"{content}\n\n"

    with open(f'{directory}/{i}.md', 'w', encoding='utf-8') as file:
        file.write(markdown_content)

# %% [markdown]
# ## Step 4: Chunk the Markdown Data

# %% [markdown]
# Using LangChain's `RecursiveCharacterTextSplitter`, split the markdown texts into smaller chunks that will be stored in the vector database.

# %%
markdown_texts = []
for filename in os.listdir(directory):
  if filename.endswith(".md"):
    with open(os.path.join(directory, filename), 'r', encoding='utf-8') as file:
      markdown_content = file.read()
      html_content = markdown.markdown(markdown_content)
      markdown_texts.append(html_content)

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=50)
documents = text_splitter.create_documents(markdown_texts)

# %%
markdown_texts
# Out:
# ['<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>طمس لوحات المركبة.</p>',
#  '<h1>الغرامة المالية 100 - 150 ريال</h1>\n<p>قيادة المركبة في الأسواق التي لا يسمح بالقيادة فيها.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>عدم ربط حزام الأمان.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>استعمال المركبة لغير الغرض الذي رخصت من أجله.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>القيادة على أكتاف الطريق وعلى الأرصفة أو المسارات التي يمنع القيادة فيها.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم قيام السائق الذي يرغب في تغيير مساره بإعطاء الأفضلية لسائق المركبة التي تسير في اتجاه مستقيم في حال سير المركبتين متحاذيتين بشكل متواز.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>نقل الركاب في الأماكن غير المخصصة لهم في المركبة.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>قيام السائق بتخطي أرتال المركبات أمام إشارات المرور أو نقاط الضبط الأمني باستخدام كتف الطريق أو المسار المخصص للالتفاف.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم إعطاء أفضلية المرور لوسائل النقل العام كالقطارات أو الحافلات وما في حكمها في حال سيرها على المسارات المخصصة لها.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم الوقوف وقوفاً تاماً عند إشارة (أمامك أفضلية) في حالة مرور مركبات على الطريق المعطاة له الأفضلية.</p>',
#  '<h1>الغرامة المالية 100 - 150 ريال</h1>\n<p>عدم إعطاء أفضلية المرور للمشاة أثناء عبورهم في المسارات المخصصة لهم.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم إعطاء الأفضلية للمركبات التي على الطريق الرئيسي في حالة عدم وجود إشارة أفضلية.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>تجاوز إشارة المرور الضوئية أثناء الضوء الأحمر.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عدم إعطاء أفضلية المرور لمركبات المواكب الرسمية أو الطوارئ.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>تركيب تجهيزات في المركبة كتلك الخاصة بالمركبات الرسمية ومركبات الطوارئ.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم التقيد بإشارات رجل الأمن اليدوية عند تنظيمه للحركة وعدم إعطاء إشارته الأولوية على الإشارات الضوئية.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عدم استخدام الأنوار اللازمة عند السير ليلاً أو في الأحوال الجوية التي تكون فيها الرؤية غير واضحة.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>الوقوف في أماكن وقوف ذوي الاحتياجات الخاصة من غير هذه الفئة المسموح لها.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>التجمهر في مواقع التفحيط.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>قيام سائق الدراجة الآلية أو العادية - أو ما في حكمهما - بالتعلق بأي مركبة أخرى، أو سحب أو حمل أشياء تعرض مستخدمي الطريق للخطر.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>عدم الالتزام بحدود المسارات المحددة على الطريق.</p>',
#  '<h1>الغرامة المالية 100 - 150 ريال</h1>\n<p>ترك المركبة مفتوحة وفي وضع التشغيل بعد مغادرتها.</p>',
#  '<h1>الغرامة المالية 5000 - 10000 ريال</h1>\n<p>قيادة المركبة تحت تأثير مسكر أو مخدر، أو عقاقير محذر من القيادة تحت تأثيرها.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>دخول الشاحنات والمعدات الثقيلة وما في حكمهما إلى المدن أو الخروج منها في الأوقات غير المسموح بها.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>الانشغال بغير الطريق أثناء قيادة المركبة.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>التحرك بالمركبة بسرعة عالية، بحيث تحدث الإطارات صوتاً عالياً.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>رفض إبراز الوثائق الخاصة بالسائق أو المركبة للمصرح لهم الاطلاع عليها.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>زيادة أبعاد الحمولة المنقولة لمركبات النقل الثقيل على الحد المسموح به.</p>',
#  '<h1>الغرامة المالية 5000 - 10000 ريال</h1>\n<p>طمس رقم هيكل المركبة أو محاولة طمسه.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>قيادة مركبة دون توافر التجهيزات اللازمة، مثل المكابح والأنوار وما في حكمهما.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>زيادة أبعاد الحمولة المنقولة لمركبات النقل الخفيف على الحد المسموح به.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>قيادة المركبة برخصة قيادة لا تتناسب مع حجم المركبة ونوع استخدامها.</p>',
#  '<h1>الغرامة المالية 5000 - 10000 ريال</h1>\n<p>القيام بأعمال الطرق قبل التنسيق مع الإدارة المختصة.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>المراوغة بسرعة بين المركبات على الطرق العامة.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عدم وجود إنارة جانبية أو عواكس أو سواتر للشاحنات والمقطورات.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>قيادة المركبة قبل الحصول على رخصة قيادة أو في حال سحب الرخصة.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>قيادة المركبة داخل الأنفاق من غير إضاءة أنوارها.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم إعطاء أفضلية المرور في ملتقيات الطرق أو تقاطعاتها لسائق المركبة المتقدم على غيره في حال عدم وجود لوحات تنظم ذلك.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>قيام سائق مركبة الطوارئ باستعمال المنبهات الخاصة بها من غير ضرورة.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عدم تثبيت اللوحة في مكانها المخصص.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>العبث بعلامات الطريق أو العاكسات أو الشاحنات المنظمة لحركة السير.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>عدم استخدام إشارة الالتفاف عند التحول لليمين أو اليسار أو التجاوز أو تغيير المسار.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>قيادة المركبة بالاتجاه المعاكس لحركة السير.</p>',
#  '<h1>الغرامة المالية 5000 - 10000 ريال</h1>\n<p>سماح أصحاب الحيوانات بعبور حيواناتهم من غير الأماكن المخصصة لها، أو دون التنسيق مع الجهات المختصة.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>الرجوع إلى الخلف في الطريق العام لمسافة تزيد على عشرين متراً.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>تظليل زجاج المركبة دون التقيد بالضوابط التي تضعها الإدارة المختصة.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>عدم ترك السائق مسافة كافية بين مركبته والمركبة التي أمامه، تسمح له بتفادي وقوع حادث.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم قيام السائق في حال تغيير اتجاهه بالدوران للخلف بإعطاء أفضلية المرور للمركبات القادمة من الاتجاهات الأخرى.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>تسيير مركبات الأشغال العامة على الطرق قبل اتخاذ الإجراءات اللازمة لتلافي أضرارها، بما في ذلك عدم وضع الشرائح العاكسة على جانبي مؤخرة المركبة.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عدم إنهاء إجراءات تعديل مجال استعمال المركبة.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>استخدام أجهزة غير مصرح بها في المركبة أو وضع شعارات أو ملصقات تتنافى مع الآداب العامة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>عدم استخدام مقاعد الأمان المخصصة للأطفال.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم إعطاء الأفضلية للمركبات التي بداخل الدوار من قبل المركبات التي خارجه في حالة عدم وجود إشارات ضوئية أو رجل أمن يوجه السير.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>التجاوز في المناطق التي يمنع فيها التجاوز، مثل المنعطفات والمرتفعات.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>نقل عدد من الركاب يزيد على العدد المحدد في رخصة السير.</p>',
#  '<h1>الغرامة المالية 5000 - 10000 ريال</h1>\n<p>استخدام لوحات غير عائدة للمركبة.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عدم إخراج المركبة المعدة للتصدير خلال المدة المحددة.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>تسيير مركبة تحدث تلويثاً للبيئة على الطرق العامة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>استعمال المكابح (الفرامل) بشكل مفاجئ لغير ضرورة.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>قيادة المركبة بلوحات غير واضحة أو بها تلف.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>القيادة على الطريق بمركبات مخصصة للاقتناء.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عبور المشاة للطرق السريعة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>القيادة برخصة قيادة صلاحيتها منتهية.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>التجمهر في موقع الحادث.</p>',
#  '<h1>الغرامة المالية 5000 - 10000 ريال</h1>\n<p>المجازفة بعبور الأودية والشعاب أثناء جريانها.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>عدم تقديم المركبة للفحص الفني الدوري.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>استخدام السائق بيده أي جهاز محمول أثناء سير المركبة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>عدم اتخاذ الاحتياطات اللازمة عند إيقاف المركبة في حالات الطوارئ على الطرق العامة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>عدم التقيد بتنظيمات السير عند تقاطعات الطرق.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>إجراء سباق للمركبات على الطرق العامة، أو السير في مواكب دون الحصول على تصريح.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم قيام السائق في حال إغلاق جزء من الطريق بإعطاء الأفضلية لمن كان طريقه مفتوحاً.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم الوقوف تماماً عند إشارة قف.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>عدم قيام أصحاب الحيوانات بإبعادها عن حرم الطريق المعتمد.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>وضع حواجز داخل المركبة أو خارجها تعوق رؤية السائق.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>سير المركبة بلا لوحة خلفية، أو بلا لوحات.</p>',
#  '<h1>الغرامة المالية 100 - 150 ريال</h1>\n<p>عبور المشاة للطرق من غير الأماكن المخصصة لهم.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>استخدام لوحات غير صادرة من الإدارة المختصة.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>عدم التزام الشاحنات والمعدات الثقيلة بالسير في المسار الآمن في الطريق المتعدد المسارات.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>إحداث ضوضاء باستعمال أجهزة من داخل المركبة، أو ارتكاب أي سلوك يتنافى مع الآداب العامة أثناء القيادة.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>إجراء أي تعديل أو إضافة على جسم المركبة أو هيكلها، يغير معالمها أو تجهيزاتها الأساسية دون اتخاذ الإجراءات النظامية.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>عدم حمل رخصة القيادة أو رخصة السير أثناء القيادة.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم تغطية الحمولة المنقولة وتثبيتها.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>مخالفة تنظيمات السير على الطرق.</p>',
#  '<h1>الغرامة المالية 100 - 150 ريال</h1>\n<p>عدم وجود تأمين ساري للمركبة.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>عدم توافر المتطلبات النظامية للمقطورة.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم إعطاء الأفضلية للمركبة القادمة من اليمين عند الوصول إلى تقاطع متساوي الأفضلية في آن واحد وعندما لا يكون هناك إشارات أولوية.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>ترك أجسام على الطرق العامة تعرض السلامة العامة للخطر.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>سير المركبة بلا لوحة أمامية.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>إساءة استعمال منبه المركبة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>ترك الأطفال دون سن العاشرة في المركبة دون مرافق راشد.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>الوقوف على خطوط السكة الحديدية.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>ترك المركبة في طريق منحدرة مع عدم اتخاذ الاحتياطات اللازمة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>رمي أجسام خارج المركبة.</p>',
#  '<h1>الغرامة المالية 100 - 150 ريال</h1>\n<p>عدم تقيد المشاة بالإشارات الخاصة بهم.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>عدم ارتداء الخوذة أثناء قيادة الدراجة الآلية.</p>',
#  '<h1>الغرامة المالية 100 - 150 ريال</h1>\n<p>وقوف المركبة في أماكن غير مخصصة للوقوف.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>ملاحقة مركبات الطوارئ أثناء استعمال المنبهات الخاصة بها.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>وضع كتابة أو رسم أو ملصق أو أي بيان آخر على جسم المركبة دون موافقة الجهات المختصة.</p>',
#  '<h1>الغرامة المالية 300 - 500 ريال</h1>\n<p>التباطؤ في السير على نحو يعرقل الحركة.</p>',
#  '<h1>الغرامة المالية 500 - 900 ريال</h1>\n<p>عدم إعطاء أفضلية المرور للمركبات القادمة من طريق رئيسي في حالة تقاطعها مع طريق فرعي أو طريق ترابي.</p>',
#  '<h1>الغرامة المالية 1000 - 2000 ريال</h1>\n<p>النزول أو الركوب أثناء سير المركبات.</p>',
#  '<h1>الغرامة المالية 150 - 300 ريال</h1>\n<p>مخالفة قواعد استعمال أنوار التلاقي.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>تجاوز حافلات النقل المدرسي عند توقفها للتحميل أو التنزيل.</p>',
#  '<h1>الغرامة المالية 3000 - 6000 ريال</h1>\n<p>عدم الوقوف عند مراكز الضبط الأمني أو نقاط التفتيش أو عدم الوقوف للدورية الأمنية عند وجود توجيه أو علامة توجب الوقوف.</p>']

# %%
documents
# Out:
# [Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>طمس لوحات المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 100 - 150 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة المركبة في الأسواق التي لا يسمح بالقيادة'),
#  Document(metadata={}, page_content='في الأسواق التي لا يسمح بالقيادة فيها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم ربط حزام الأمان.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>استعمال المركبة لغير الغرض الذي رخصت من'),
#  Document(metadata={}, page_content='المركبة لغير الغرض الذي رخصت من أجله.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>القيادة على أكتاف الطريق وعلى الأرصفة أو'),
#  Document(metadata={}, page_content='على أكتاف الطريق وعلى الأرصفة أو المسارات التي'),
#  Document(metadata={}, page_content='أكتاف الطريق وعلى الأرصفة أو المسارات التي يمنع'),
#  Document(metadata={}, page_content='الطريق وعلى الأرصفة أو المسارات التي يمنع القيادة'),
#  Document(metadata={}, page_content='الأرصفة أو المسارات التي يمنع القيادة فيها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم قيام السائق الذي يرغب في تغيير مساره'),
#  Document(metadata={}, page_content='قيام السائق الذي يرغب في تغيير مساره بإعطاء'),
#  Document(metadata={}, page_content='السائق الذي يرغب في تغيير مساره بإعطاء الأفضلية'),
#  Document(metadata={}, page_content='الذي يرغب في تغيير مساره بإعطاء الأفضلية لسائق'),
#  Document(metadata={}, page_content='يرغب في تغيير مساره بإعطاء الأفضلية لسائق المركبة'),
#  Document(metadata={}, page_content='في تغيير مساره بإعطاء الأفضلية لسائق المركبة التي'),
#  Document(metadata={}, page_content='مساره بإعطاء الأفضلية لسائق المركبة التي تسير في'),
#  Document(metadata={}, page_content='بإعطاء الأفضلية لسائق المركبة التي تسير في اتجاه'),
#  Document(metadata={}, page_content='الأفضلية لسائق المركبة التي تسير في اتجاه مستقيم'),
#  Document(metadata={}, page_content='لسائق المركبة التي تسير في اتجاه مستقيم في حال'),
#  Document(metadata={}, page_content='المركبة التي تسير في اتجاه مستقيم في حال سير'),
#  Document(metadata={}, page_content='التي تسير في اتجاه مستقيم في حال سير المركبتين'),
#  Document(metadata={}, page_content='في اتجاه مستقيم في حال سير المركبتين متحاذيتين'),
#  Document(metadata={}, page_content='اتجاه مستقيم في حال سير المركبتين متحاذيتين بشكل'),
#  Document(metadata={}, page_content='في حال سير المركبتين متحاذيتين بشكل متواز.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>نقل الركاب في الأماكن غير المخصصة لهم في'),
#  Document(metadata={}, page_content='الركاب في الأماكن غير المخصصة لهم في المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيام السائق بتخطي أرتال المركبات أمام إشارات'),
#  Document(metadata={}, page_content='السائق بتخطي أرتال المركبات أمام إشارات المرور أو'),
#  Document(metadata={}, page_content='بتخطي أرتال المركبات أمام إشارات المرور أو نقاط'),
#  Document(metadata={}, page_content='أرتال المركبات أمام إشارات المرور أو نقاط الضبط'),
#  Document(metadata={}, page_content='المركبات أمام إشارات المرور أو نقاط الضبط الأمني'),
#  Document(metadata={}, page_content='أمام إشارات المرور أو نقاط الضبط الأمني باستخدام'),
#  Document(metadata={}, page_content='إشارات المرور أو نقاط الضبط الأمني باستخدام كتف'),
#  Document(metadata={}, page_content='المرور أو نقاط الضبط الأمني باستخدام كتف الطريق'),
#  Document(metadata={}, page_content='أو نقاط الضبط الأمني باستخدام كتف الطريق أو'),
#  Document(metadata={}, page_content='نقاط الضبط الأمني باستخدام كتف الطريق أو المسار'),
#  Document(metadata={}, page_content='الضبط الأمني باستخدام كتف الطريق أو المسار المخصص'),
#  Document(metadata={}, page_content='كتف الطريق أو المسار المخصص للالتفاف.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء أفضلية المرور لوسائل النقل العام'),
#  Document(metadata={}, page_content='إعطاء أفضلية المرور لوسائل النقل العام كالقطارات'),
#  Document(metadata={}, page_content='أفضلية المرور لوسائل النقل العام كالقطارات أو'),
#  Document(metadata={}, page_content='المرور لوسائل النقل العام كالقطارات أو الحافلات'),
#  Document(metadata={}, page_content='لوسائل النقل العام كالقطارات أو الحافلات وما في'),
#  Document(metadata={}, page_content='النقل العام كالقطارات أو الحافلات وما في حكمها في'),
#  Document(metadata={}, page_content='العام كالقطارات أو الحافلات وما في حكمها في حال'),
#  Document(metadata={}, page_content='كالقطارات أو الحافلات وما في حكمها في حال سيرها'),
#  Document(metadata={}, page_content='أو الحافلات وما في حكمها في حال سيرها على'),
#  Document(metadata={}, page_content='الحافلات وما في حكمها في حال سيرها على المسارات'),
#  Document(metadata={}, page_content='وما في حكمها في حال سيرها على المسارات المخصصة'),
#  Document(metadata={}, page_content='حكمها في حال سيرها على المسارات المخصصة لها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم الوقوف وقوفاً تاماً عند إشارة (أمامك'),
#  Document(metadata={}, page_content='الوقوف وقوفاً تاماً عند إشارة (أمامك أفضلية) في'),
#  Document(metadata={}, page_content='وقوفاً تاماً عند إشارة (أمامك أفضلية) في حالة'),
#  Document(metadata={}, page_content='تاماً عند إشارة (أمامك أفضلية) في حالة مرور'),
#  Document(metadata={}, page_content='عند إشارة (أمامك أفضلية) في حالة مرور مركبات على'),
#  Document(metadata={}, page_content='(أمامك أفضلية) في حالة مرور مركبات على الطريق'),
#  Document(metadata={}, page_content='أفضلية) في حالة مرور مركبات على الطريق المعطاة له'),
#  Document(metadata={}, page_content='مرور مركبات على الطريق المعطاة له الأفضلية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 100 - 150 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء أفضلية المرور للمشاة أثناء عبورهم في'),
#  Document(metadata={}, page_content='أفضلية المرور للمشاة أثناء عبورهم في المسارات'),
#  Document(metadata={}, page_content='المرور للمشاة أثناء عبورهم في المسارات المخصصة'),
#  Document(metadata={}, page_content='للمشاة أثناء عبورهم في المسارات المخصصة لهم.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء الأفضلية للمركبات التي على الطريق'),
#  Document(metadata={}, page_content='إعطاء الأفضلية للمركبات التي على الطريق الرئيسي'),
#  Document(metadata={}, page_content='الأفضلية للمركبات التي على الطريق الرئيسي في حالة'),
#  Document(metadata={}, page_content='للمركبات التي على الطريق الرئيسي في حالة عدم وجود'),
#  Document(metadata={}, page_content='التي على الطريق الرئيسي في حالة عدم وجود إشارة'),
#  Document(metadata={}, page_content='الطريق الرئيسي في حالة عدم وجود إشارة أفضلية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>تجاوز إشارة المرور الضوئية أثناء الضوء'),
#  Document(metadata={}, page_content='إشارة المرور الضوئية أثناء الضوء الأحمر.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء أفضلية المرور لمركبات المواكب'),
#  Document(metadata={}, page_content='إعطاء أفضلية المرور لمركبات المواكب الرسمية أو'),
#  Document(metadata={}, page_content='المرور لمركبات المواكب الرسمية أو الطوارئ.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>تركيب تجهيزات في المركبة كتلك الخاصة بالمركبات'),
#  Document(metadata={}, page_content='تجهيزات في المركبة كتلك الخاصة بالمركبات الرسمية'),
#  Document(metadata={}, page_content='في المركبة كتلك الخاصة بالمركبات الرسمية ومركبات'),
#  Document(metadata={}, page_content='الخاصة بالمركبات الرسمية ومركبات الطوارئ.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم التقيد بإشارات رجل الأمن اليدوية عند'),
#  Document(metadata={}, page_content='التقيد بإشارات رجل الأمن اليدوية عند تنظيمه'),
#  Document(metadata={}, page_content='بإشارات رجل الأمن اليدوية عند تنظيمه للحركة وعدم'),
#  Document(metadata={}, page_content='رجل الأمن اليدوية عند تنظيمه للحركة وعدم إعطاء'),
#  Document(metadata={}, page_content='الأمن اليدوية عند تنظيمه للحركة وعدم إعطاء إشارته'),
#  Document(metadata={}, page_content='عند تنظيمه للحركة وعدم إعطاء إشارته الأولوية على'),
#  Document(metadata={}, page_content='للحركة وعدم إعطاء إشارته الأولوية على الإشارات'),
#  Document(metadata={}, page_content='إعطاء إشارته الأولوية على الإشارات الضوئية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم استخدام الأنوار اللازمة عند السير ليلاً أو'),
#  Document(metadata={}, page_content='استخدام الأنوار اللازمة عند السير ليلاً أو في'),
#  Document(metadata={}, page_content='الأنوار اللازمة عند السير ليلاً أو في الأحوال'),
#  Document(metadata={}, page_content='اللازمة عند السير ليلاً أو في الأحوال الجوية التي'),
#  Document(metadata={}, page_content='عند السير ليلاً أو في الأحوال الجوية التي تكون'),
#  Document(metadata={}, page_content='السير ليلاً أو في الأحوال الجوية التي تكون فيها'),
#  Document(metadata={}, page_content='ليلاً أو في الأحوال الجوية التي تكون فيها الرؤية'),
#  Document(metadata={}, page_content='أو في الأحوال الجوية التي تكون فيها الرؤية غير'),
#  Document(metadata={}, page_content='الجوية التي تكون فيها الرؤية غير واضحة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>الوقوف في أماكن وقوف ذوي الاحتياجات الخاصة من'),
#  Document(metadata={}, page_content='في أماكن وقوف ذوي الاحتياجات الخاصة من غير هذه'),
#  Document(metadata={}, page_content='أماكن وقوف ذوي الاحتياجات الخاصة من غير هذه الفئة'),
#  Document(metadata={}, page_content='ذوي الاحتياجات الخاصة من غير هذه الفئة المسموح'),
#  Document(metadata={}, page_content='الخاصة من غير هذه الفئة المسموح لها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>التجمهر في مواقع التفحيط.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيام سائق الدراجة الآلية أو العادية - أو ما في'),
#  Document(metadata={}, page_content='سائق الدراجة الآلية أو العادية - أو ما في حكمهما'),
#  Document(metadata={}, page_content='الدراجة الآلية أو العادية - أو ما في حكمهما -'),
#  Document(metadata={}, page_content='الآلية أو العادية - أو ما في حكمهما - بالتعلق بأي'),
#  Document(metadata={}, page_content='أو العادية - أو ما في حكمهما - بالتعلق بأي مركبة'),
#  Document(metadata={}, page_content='- أو ما في حكمهما - بالتعلق بأي مركبة أخرى، أو'),
#  Document(metadata={}, page_content='أو ما في حكمهما - بالتعلق بأي مركبة أخرى، أو سحب'),
#  Document(metadata={}, page_content='ما في حكمهما - بالتعلق بأي مركبة أخرى، أو سحب أو'),
#  Document(metadata={}, page_content='في حكمهما - بالتعلق بأي مركبة أخرى، أو سحب أو حمل'),
#  Document(metadata={}, page_content='- بالتعلق بأي مركبة أخرى، أو سحب أو حمل أشياء'),
#  Document(metadata={}, page_content='بالتعلق بأي مركبة أخرى، أو سحب أو حمل أشياء تعرض'),
#  Document(metadata={}, page_content='بأي مركبة أخرى، أو سحب أو حمل أشياء تعرض مستخدمي'),
#  Document(metadata={}, page_content='أخرى، أو سحب أو حمل أشياء تعرض مستخدمي الطريق'),
#  Document(metadata={}, page_content='سحب أو حمل أشياء تعرض مستخدمي الطريق للخطر.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم الالتزام بحدود المسارات المحددة على'),
#  Document(metadata={}, page_content='الالتزام بحدود المسارات المحددة على الطريق.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 100 - 150 ريال</h1>'),
#  Document(metadata={}, page_content='<p>ترك المركبة مفتوحة وفي وضع التشغيل بعد'),
#  Document(metadata={}, page_content='المركبة مفتوحة وفي وضع التشغيل بعد مغادرتها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 5000 - 10000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة المركبة تحت تأثير مسكر أو مخدر، أو'),
#  Document(metadata={}, page_content='المركبة تحت تأثير مسكر أو مخدر، أو عقاقير محذر من'),
#  Document(metadata={}, page_content='تحت تأثير مسكر أو مخدر، أو عقاقير محذر من القيادة'),
#  Document(metadata={}, page_content='تأثير مسكر أو مخدر، أو عقاقير محذر من القيادة تحت'),
#  Document(metadata={}, page_content='مخدر، أو عقاقير محذر من القيادة تحت تأثيرها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>دخول الشاحنات والمعدات الثقيلة وما في حكمهما'),
#  Document(metadata={}, page_content='الشاحنات والمعدات الثقيلة وما في حكمهما إلى المدن'),
#  Document(metadata={}, page_content='والمعدات الثقيلة وما في حكمهما إلى المدن أو'),
#  Document(metadata={}, page_content='الثقيلة وما في حكمهما إلى المدن أو الخروج منها في'),
#  Document(metadata={}, page_content='وما في حكمهما إلى المدن أو الخروج منها في الأوقات'),
#  Document(metadata={}, page_content='في حكمهما إلى المدن أو الخروج منها في الأوقات غير'),
#  Document(metadata={}, page_content='إلى المدن أو الخروج منها في الأوقات غير المسموح'),
#  Document(metadata={}, page_content='أو الخروج منها في الأوقات غير المسموح بها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>الانشغال بغير الطريق أثناء قيادة المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>التحرك بالمركبة بسرعة عالية، بحيث تحدث'),
#  Document(metadata={}, page_content='بالمركبة بسرعة عالية، بحيث تحدث الإطارات صوتاً'),
#  Document(metadata={}, page_content='بسرعة عالية، بحيث تحدث الإطارات صوتاً عالياً.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>رفض إبراز الوثائق الخاصة بالسائق أو المركبة'),
#  Document(metadata={}, page_content='إبراز الوثائق الخاصة بالسائق أو المركبة للمصرح'),
#  Document(metadata={}, page_content='الوثائق الخاصة بالسائق أو المركبة للمصرح لهم'),
#  Document(metadata={}, page_content='الخاصة بالسائق أو المركبة للمصرح لهم الاطلاع'),
#  Document(metadata={}, page_content='بالسائق أو المركبة للمصرح لهم الاطلاع عليها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>زيادة أبعاد الحمولة المنقولة لمركبات النقل'),
#  Document(metadata={}, page_content='أبعاد الحمولة المنقولة لمركبات النقل الثقيل على'),
#  Document(metadata={}, page_content='الحمولة المنقولة لمركبات النقل الثقيل على الحد'),
#  Document(metadata={}, page_content='المنقولة لمركبات النقل الثقيل على الحد المسموح'),
#  Document(metadata={}, page_content='لمركبات النقل الثقيل على الحد المسموح به.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 5000 - 10000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>طمس رقم هيكل المركبة أو محاولة طمسه.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة مركبة دون توافر التجهيزات اللازمة، مثل'),
#  Document(metadata={}, page_content='مركبة دون توافر التجهيزات اللازمة، مثل المكابح'),
#  Document(metadata={}, page_content='دون توافر التجهيزات اللازمة، مثل المكابح والأنوار'),
#  Document(metadata={}, page_content='توافر التجهيزات اللازمة، مثل المكابح والأنوار وما'),
#  Document(metadata={}, page_content='التجهيزات اللازمة، مثل المكابح والأنوار وما في'),
#  Document(metadata={}, page_content='اللازمة، مثل المكابح والأنوار وما في حكمهما.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>زيادة أبعاد الحمولة المنقولة لمركبات النقل'),
#  Document(metadata={}, page_content='أبعاد الحمولة المنقولة لمركبات النقل الخفيف على'),
#  Document(metadata={}, page_content='الحمولة المنقولة لمركبات النقل الخفيف على الحد'),
#  Document(metadata={}, page_content='المنقولة لمركبات النقل الخفيف على الحد المسموح'),
#  Document(metadata={}, page_content='لمركبات النقل الخفيف على الحد المسموح به.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة المركبة برخصة قيادة لا تتناسب مع حجم'),
#  Document(metadata={}, page_content='المركبة برخصة قيادة لا تتناسب مع حجم المركبة ونوع'),
#  Document(metadata={}, page_content='لا تتناسب مع حجم المركبة ونوع استخدامها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 5000 - 10000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>القيام بأعمال الطرق قبل التنسيق مع الإدارة'),
#  Document(metadata={}, page_content='بأعمال الطرق قبل التنسيق مع الإدارة المختصة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>المراوغة بسرعة بين المركبات على الطرق'),
#  Document(metadata={}, page_content='بسرعة بين المركبات على الطرق العامة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم وجود إنارة جانبية أو عواكس أو سواتر'),
#  Document(metadata={}, page_content='وجود إنارة جانبية أو عواكس أو سواتر للشاحنات'),
#  Document(metadata={}, page_content='جانبية أو عواكس أو سواتر للشاحنات والمقطورات.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة المركبة قبل الحصول على رخصة قيادة أو في'),
#  Document(metadata={}, page_content='المركبة قبل الحصول على رخصة قيادة أو في حال سحب'),
#  Document(metadata={}, page_content='الحصول على رخصة قيادة أو في حال سحب الرخصة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة المركبة داخل الأنفاق من غير إضاءة'),
#  Document(metadata={}, page_content='المركبة داخل الأنفاق من غير إضاءة أنوارها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء أفضلية المرور في ملتقيات الطرق أو'),
#  Document(metadata={}, page_content='إعطاء أفضلية المرور في ملتقيات الطرق أو تقاطعاتها'),
#  Document(metadata={}, page_content='أفضلية المرور في ملتقيات الطرق أو تقاطعاتها لسائق'),
#  Document(metadata={}, page_content='في ملتقيات الطرق أو تقاطعاتها لسائق المركبة'),
#  Document(metadata={}, page_content='ملتقيات الطرق أو تقاطعاتها لسائق المركبة المتقدم'),
#  Document(metadata={}, page_content='الطرق أو تقاطعاتها لسائق المركبة المتقدم على غيره'),
#  Document(metadata={}, page_content='أو تقاطعاتها لسائق المركبة المتقدم على غيره في'),
#  Document(metadata={}, page_content='تقاطعاتها لسائق المركبة المتقدم على غيره في حال'),
#  Document(metadata={}, page_content='لسائق المركبة المتقدم على غيره في حال عدم وجود'),
#  Document(metadata={}, page_content='المركبة المتقدم على غيره في حال عدم وجود لوحات'),
#  Document(metadata={}, page_content='المتقدم على غيره في حال عدم وجود لوحات تنظم'),
#  Document(metadata={}, page_content='على غيره في حال عدم وجود لوحات تنظم ذلك.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيام سائق مركبة الطوارئ باستعمال المنبهات'),
#  Document(metadata={}, page_content='سائق مركبة الطوارئ باستعمال المنبهات الخاصة بها'),
#  Document(metadata={}, page_content='مركبة الطوارئ باستعمال المنبهات الخاصة بها من غير'),
#  Document(metadata={}, page_content='باستعمال المنبهات الخاصة بها من غير ضرورة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم تثبيت اللوحة في مكانها المخصص.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>العبث بعلامات الطريق أو العاكسات أو الشاحنات'),
#  Document(metadata={}, page_content='بعلامات الطريق أو العاكسات أو الشاحنات المنظمة'),
#  Document(metadata={}, page_content='الطريق أو العاكسات أو الشاحنات المنظمة لحركة'),
#  Document(metadata={}, page_content='أو العاكسات أو الشاحنات المنظمة لحركة السير.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم استخدام إشارة الالتفاف عند التحول لليمين'),
#  Document(metadata={}, page_content='استخدام إشارة الالتفاف عند التحول لليمين أو'),
#  Document(metadata={}, page_content='إشارة الالتفاف عند التحول لليمين أو اليسار أو'),
#  Document(metadata={}, page_content='الالتفاف عند التحول لليمين أو اليسار أو التجاوز'),
#  Document(metadata={}, page_content='عند التحول لليمين أو اليسار أو التجاوز أو تغيير'),
#  Document(metadata={}, page_content='لليمين أو اليسار أو التجاوز أو تغيير المسار.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة المركبة بالاتجاه المعاكس لحركة'),
#  Document(metadata={}, page_content='المركبة بالاتجاه المعاكس لحركة السير.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 5000 - 10000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>سماح أصحاب الحيوانات بعبور حيواناتهم من غير'),
#  Document(metadata={}, page_content='أصحاب الحيوانات بعبور حيواناتهم من غير الأماكن'),
#  Document(metadata={}, page_content='الحيوانات بعبور حيواناتهم من غير الأماكن المخصصة'),
#  Document(metadata={}, page_content='بعبور حيواناتهم من غير الأماكن المخصصة لها، أو'),
#  Document(metadata={}, page_content='حيواناتهم من غير الأماكن المخصصة لها، أو دون'),
#  Document(metadata={}, page_content='من غير الأماكن المخصصة لها، أو دون التنسيق مع'),
#  Document(metadata={}, page_content='غير الأماكن المخصصة لها، أو دون التنسيق مع الجهات'),
#  Document(metadata={}, page_content='لها، أو دون التنسيق مع الجهات المختصة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>الرجوع إلى الخلف في الطريق العام لمسافة تزيد'),
#  Document(metadata={}, page_content='إلى الخلف في الطريق العام لمسافة تزيد على عشرين'),
#  Document(metadata={}, page_content='في الطريق العام لمسافة تزيد على عشرين متراً.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>تظليل زجاج المركبة دون التقيد بالضوابط التي'),
#  Document(metadata={}, page_content='زجاج المركبة دون التقيد بالضوابط التي تضعها'),
#  Document(metadata={}, page_content='المركبة دون التقيد بالضوابط التي تضعها الإدارة'),
#  Document(metadata={}, page_content='التقيد بالضوابط التي تضعها الإدارة المختصة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم ترك السائق مسافة كافية بين مركبته والمركبة'),
#  Document(metadata={}, page_content='ترك السائق مسافة كافية بين مركبته والمركبة التي'),
#  Document(metadata={}, page_content='مسافة كافية بين مركبته والمركبة التي أمامه، تسمح'),
#  Document(metadata={}, page_content='كافية بين مركبته والمركبة التي أمامه، تسمح له'),
#  Document(metadata={}, page_content='بين مركبته والمركبة التي أمامه، تسمح له بتفادي'),
#  Document(metadata={}, page_content='مركبته والمركبة التي أمامه، تسمح له بتفادي وقوع'),
#  Document(metadata={}, page_content='التي أمامه، تسمح له بتفادي وقوع حادث.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم قيام السائق في حال تغيير اتجاهه بالدوران'),
#  Document(metadata={}, page_content='قيام السائق في حال تغيير اتجاهه بالدوران للخلف'),
#  Document(metadata={}, page_content='السائق في حال تغيير اتجاهه بالدوران للخلف بإعطاء'),
#  Document(metadata={}, page_content='في حال تغيير اتجاهه بالدوران للخلف بإعطاء أفضلية'),
#  Document(metadata={}, page_content='تغيير اتجاهه بالدوران للخلف بإعطاء أفضلية المرور'),
#  Document(metadata={}, page_content='بالدوران للخلف بإعطاء أفضلية المرور للمركبات'),
#  Document(metadata={}, page_content='للخلف بإعطاء أفضلية المرور للمركبات القادمة من'),
#  Document(metadata={}, page_content='أفضلية المرور للمركبات القادمة من الاتجاهات'),
#  Document(metadata={}, page_content='المرور للمركبات القادمة من الاتجاهات الأخرى.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>تسيير مركبات الأشغال العامة على الطرق قبل'),
#  Document(metadata={}, page_content='مركبات الأشغال العامة على الطرق قبل اتخاذ'),
#  Document(metadata={}, page_content='الأشغال العامة على الطرق قبل اتخاذ الإجراءات'),
#  Document(metadata={}, page_content='العامة على الطرق قبل اتخاذ الإجراءات اللازمة'),
#  Document(metadata={}, page_content='على الطرق قبل اتخاذ الإجراءات اللازمة لتلافي'),
#  Document(metadata={}, page_content='الطرق قبل اتخاذ الإجراءات اللازمة لتلافي أضرارها،'),
#  Document(metadata={}, page_content='قبل اتخاذ الإجراءات اللازمة لتلافي أضرارها، بما'),
#  Document(metadata={}, page_content='اتخاذ الإجراءات اللازمة لتلافي أضرارها، بما في'),
#  Document(metadata={}, page_content='الإجراءات اللازمة لتلافي أضرارها، بما في ذلك عدم'),
#  Document(metadata={}, page_content='اللازمة لتلافي أضرارها، بما في ذلك عدم وضع'),
#  Document(metadata={}, page_content='لتلافي أضرارها، بما في ذلك عدم وضع الشرائح'),
#  Document(metadata={}, page_content='أضرارها، بما في ذلك عدم وضع الشرائح العاكسة على'),
#  Document(metadata={}, page_content='بما في ذلك عدم وضع الشرائح العاكسة على جانبي'),
#  Document(metadata={}, page_content='في ذلك عدم وضع الشرائح العاكسة على جانبي مؤخرة'),
#  Document(metadata={}, page_content='وضع الشرائح العاكسة على جانبي مؤخرة المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إنهاء إجراءات تعديل مجال استعمال'),
#  Document(metadata={}, page_content='إنهاء إجراءات تعديل مجال استعمال المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>استخدام أجهزة غير مصرح بها في المركبة أو وضع'),
#  Document(metadata={}, page_content='أجهزة غير مصرح بها في المركبة أو وضع شعارات أو'),
#  Document(metadata={}, page_content='غير مصرح بها في المركبة أو وضع شعارات أو ملصقات'),
#  Document(metadata={}, page_content='بها في المركبة أو وضع شعارات أو ملصقات تتنافى مع'),
#  Document(metadata={}, page_content='المركبة أو وضع شعارات أو ملصقات تتنافى مع الآداب'),
#  Document(metadata={}, page_content='وضع شعارات أو ملصقات تتنافى مع الآداب العامة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم استخدام مقاعد الأمان المخصصة للأطفال.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء الأفضلية للمركبات التي بداخل الدوار'),
#  Document(metadata={}, page_content='إعطاء الأفضلية للمركبات التي بداخل الدوار من قبل'),
#  Document(metadata={}, page_content='للمركبات التي بداخل الدوار من قبل المركبات التي'),
#  Document(metadata={}, page_content='التي بداخل الدوار من قبل المركبات التي خارجه في'),
#  Document(metadata={}, page_content='بداخل الدوار من قبل المركبات التي خارجه في حالة'),
#  Document(metadata={}, page_content='الدوار من قبل المركبات التي خارجه في حالة عدم'),
#  Document(metadata={}, page_content='من قبل المركبات التي خارجه في حالة عدم وجود'),
#  Document(metadata={}, page_content='قبل المركبات التي خارجه في حالة عدم وجود إشارات'),
#  Document(metadata={}, page_content='المركبات التي خارجه في حالة عدم وجود إشارات ضوئية'),
#  Document(metadata={}, page_content='التي خارجه في حالة عدم وجود إشارات ضوئية أو رجل'),
#  Document(metadata={}, page_content='خارجه في حالة عدم وجود إشارات ضوئية أو رجل أمن'),
#  Document(metadata={}, page_content='في حالة عدم وجود إشارات ضوئية أو رجل أمن يوجه'),
#  Document(metadata={}, page_content='عدم وجود إشارات ضوئية أو رجل أمن يوجه السير.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>التجاوز في المناطق التي يمنع فيها التجاوز، مثل'),
#  Document(metadata={}, page_content='في المناطق التي يمنع فيها التجاوز، مثل المنعطفات'),
#  Document(metadata={}, page_content='يمنع فيها التجاوز، مثل المنعطفات والمرتفعات.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>نقل عدد من الركاب يزيد على العدد المحدد في'),
#  Document(metadata={}, page_content='عدد من الركاب يزيد على العدد المحدد في رخصة'),
#  Document(metadata={}, page_content='الركاب يزيد على العدد المحدد في رخصة السير.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 5000 - 10000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>استخدام لوحات غير عائدة للمركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إخراج المركبة المعدة للتصدير خلال المدة'),
#  Document(metadata={}, page_content='المركبة المعدة للتصدير خلال المدة المحددة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>تسيير مركبة تحدث تلويثاً للبيئة على الطرق'),
#  Document(metadata={}, page_content='مركبة تحدث تلويثاً للبيئة على الطرق العامة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>استعمال المكابح (الفرامل) بشكل مفاجئ لغير'),
#  Document(metadata={}, page_content='المكابح (الفرامل) بشكل مفاجئ لغير ضرورة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>قيادة المركبة بلوحات غير واضحة أو بها تلف.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>القيادة على الطريق بمركبات مخصصة للاقتناء.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عبور المشاة للطرق السريعة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>القيادة برخصة قيادة صلاحيتها منتهية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>التجمهر في موقع الحادث.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 5000 - 10000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>المجازفة بعبور الأودية والشعاب أثناء'),
#  Document(metadata={}, page_content='بعبور الأودية والشعاب أثناء جريانها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم تقديم المركبة للفحص الفني الدوري.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>استخدام السائق بيده أي جهاز محمول أثناء سير'),
#  Document(metadata={}, page_content='السائق بيده أي جهاز محمول أثناء سير المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم اتخاذ الاحتياطات اللازمة عند إيقاف المركبة'),
#  Document(metadata={}, page_content='اتخاذ الاحتياطات اللازمة عند إيقاف المركبة في'),
#  Document(metadata={}, page_content='الاحتياطات اللازمة عند إيقاف المركبة في حالات'),
#  Document(metadata={}, page_content='اللازمة عند إيقاف المركبة في حالات الطوارئ على'),
#  Document(metadata={}, page_content='عند إيقاف المركبة في حالات الطوارئ على الطرق'),
#  Document(metadata={}, page_content='المركبة في حالات الطوارئ على الطرق العامة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم التقيد بتنظيمات السير عند تقاطعات'),
#  Document(metadata={}, page_content='التقيد بتنظيمات السير عند تقاطعات الطرق.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>إجراء سباق للمركبات على الطرق العامة، أو السير'),
#  Document(metadata={}, page_content='سباق للمركبات على الطرق العامة، أو السير في مواكب'),
#  Document(metadata={}, page_content='للمركبات على الطرق العامة، أو السير في مواكب دون'),
#  Document(metadata={}, page_content='على الطرق العامة، أو السير في مواكب دون الحصول'),
#  Document(metadata={}, page_content='الطرق العامة، أو السير في مواكب دون الحصول على'),
#  Document(metadata={}, page_content='أو السير في مواكب دون الحصول على تصريح.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم قيام السائق في حال إغلاق جزء من الطريق'),
#  Document(metadata={}, page_content='قيام السائق في حال إغلاق جزء من الطريق بإعطاء'),
#  Document(metadata={}, page_content='السائق في حال إغلاق جزء من الطريق بإعطاء الأفضلية'),
#  Document(metadata={}, page_content='في حال إغلاق جزء من الطريق بإعطاء الأفضلية لمن'),
#  Document(metadata={}, page_content='حال إغلاق جزء من الطريق بإعطاء الأفضلية لمن كان'),
#  Document(metadata={}, page_content='إغلاق جزء من الطريق بإعطاء الأفضلية لمن كان طريقه'),
#  Document(metadata={}, page_content='الطريق بإعطاء الأفضلية لمن كان طريقه مفتوحاً.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم الوقوف تماماً عند إشارة قف.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم قيام أصحاب الحيوانات بإبعادها عن حرم'),
#  Document(metadata={}, page_content='قيام أصحاب الحيوانات بإبعادها عن حرم الطريق'),
#  Document(metadata={}, page_content='الحيوانات بإبعادها عن حرم الطريق المعتمد.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>وضع حواجز داخل المركبة أو خارجها تعوق رؤية'),
#  Document(metadata={}, page_content='داخل المركبة أو خارجها تعوق رؤية السائق.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>سير المركبة بلا لوحة خلفية، أو بلا لوحات.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 100 - 150 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عبور المشاة للطرق من غير الأماكن المخصصة'),
#  Document(metadata={}, page_content='المشاة للطرق من غير الأماكن المخصصة لهم.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>استخدام لوحات غير صادرة من الإدارة'),
#  Document(metadata={}, page_content='لوحات غير صادرة من الإدارة المختصة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم التزام الشاحنات والمعدات الثقيلة بالسير في'),
#  Document(metadata={}, page_content='التزام الشاحنات والمعدات الثقيلة بالسير في المسار'),
#  Document(metadata={}, page_content='الشاحنات والمعدات الثقيلة بالسير في المسار الآمن'),
#  Document(metadata={}, page_content='والمعدات الثقيلة بالسير في المسار الآمن في الطريق'),
#  Document(metadata={}, page_content='الثقيلة بالسير في المسار الآمن في الطريق المتعدد'),
#  Document(metadata={}, page_content='في المسار الآمن في الطريق المتعدد المسارات.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>إحداث ضوضاء باستعمال أجهزة من داخل المركبة، أو'),
#  Document(metadata={}, page_content='ضوضاء باستعمال أجهزة من داخل المركبة، أو ارتكاب'),
#  Document(metadata={}, page_content='باستعمال أجهزة من داخل المركبة، أو ارتكاب أي سلوك'),
#  Document(metadata={}, page_content='أجهزة من داخل المركبة، أو ارتكاب أي سلوك يتنافى'),
#  Document(metadata={}, page_content='من داخل المركبة، أو ارتكاب أي سلوك يتنافى مع'),
#  Document(metadata={}, page_content='داخل المركبة، أو ارتكاب أي سلوك يتنافى مع الآداب'),
#  Document(metadata={}, page_content='أو ارتكاب أي سلوك يتنافى مع الآداب العامة أثناء'),
#  Document(metadata={}, page_content='سلوك يتنافى مع الآداب العامة أثناء القيادة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>إجراء أي تعديل أو إضافة على جسم المركبة أو'),
#  Document(metadata={}, page_content='أي تعديل أو إضافة على جسم المركبة أو هيكلها، يغير'),
#  Document(metadata={}, page_content='أو إضافة على جسم المركبة أو هيكلها، يغير معالمها'),
#  Document(metadata={}, page_content='إضافة على جسم المركبة أو هيكلها، يغير معالمها أو'),
#  Document(metadata={}, page_content='جسم المركبة أو هيكلها، يغير معالمها أو تجهيزاتها'),
#  Document(metadata={}, page_content='أو هيكلها، يغير معالمها أو تجهيزاتها الأساسية دون'),
#  Document(metadata={}, page_content='يغير معالمها أو تجهيزاتها الأساسية دون اتخاذ'),
#  Document(metadata={}, page_content='معالمها أو تجهيزاتها الأساسية دون اتخاذ الإجراءات'),
#  Document(metadata={}, page_content='الأساسية دون اتخاذ الإجراءات النظامية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم حمل رخصة القيادة أو رخصة السير أثناء'),
#  Document(metadata={}, page_content='حمل رخصة القيادة أو رخصة السير أثناء القيادة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم تغطية الحمولة المنقولة وتثبيتها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>مخالفة تنظيمات السير على الطرق.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 100 - 150 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم وجود تأمين ساري للمركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم توافر المتطلبات النظامية للمقطورة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء الأفضلية للمركبة القادمة من اليمين'),
#  Document(metadata={}, page_content='إعطاء الأفضلية للمركبة القادمة من اليمين عند'),
#  Document(metadata={}, page_content='الأفضلية للمركبة القادمة من اليمين عند الوصول إلى'),
#  Document(metadata={}, page_content='للمركبة القادمة من اليمين عند الوصول إلى تقاطع'),
#  Document(metadata={}, page_content='القادمة من اليمين عند الوصول إلى تقاطع متساوي'),
#  Document(metadata={}, page_content='من اليمين عند الوصول إلى تقاطع متساوي الأفضلية في'),
#  Document(metadata={}, page_content='اليمين عند الوصول إلى تقاطع متساوي الأفضلية في آن'),
#  Document(metadata={}, page_content='عند الوصول إلى تقاطع متساوي الأفضلية في آن واحد'),
#  Document(metadata={}, page_content='إلى تقاطع متساوي الأفضلية في آن واحد وعندما لا'),
#  Document(metadata={}, page_content='تقاطع متساوي الأفضلية في آن واحد وعندما لا يكون'),
#  Document(metadata={}, page_content='متساوي الأفضلية في آن واحد وعندما لا يكون هناك'),
#  Document(metadata={}, page_content='الأفضلية في آن واحد وعندما لا يكون هناك إشارات'),
#  Document(metadata={}, page_content='في آن واحد وعندما لا يكون هناك إشارات أولوية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>ترك أجسام على الطرق العامة تعرض السلامة العامة'),
#  Document(metadata={}, page_content='على الطرق العامة تعرض السلامة العامة للخطر.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>سير المركبة بلا لوحة أمامية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>إساءة استعمال منبه المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>ترك الأطفال دون سن العاشرة في المركبة دون'),
#  Document(metadata={}, page_content='الأطفال دون سن العاشرة في المركبة دون مرافق'),
#  Document(metadata={}, page_content='دون سن العاشرة في المركبة دون مرافق راشد.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>الوقوف على خطوط السكة الحديدية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>ترك المركبة في طريق منحدرة مع عدم اتخاذ'),
#  Document(metadata={}, page_content='المركبة في طريق منحدرة مع عدم اتخاذ الاحتياطات'),
#  Document(metadata={}, page_content='طريق منحدرة مع عدم اتخاذ الاحتياطات اللازمة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>رمي أجسام خارج المركبة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 100 - 150 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم تقيد المشاة بالإشارات الخاصة بهم.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم ارتداء الخوذة أثناء قيادة الدراجة'),
#  Document(metadata={}, page_content='ارتداء الخوذة أثناء قيادة الدراجة الآلية.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 100 - 150 ريال</h1>'),
#  Document(metadata={}, page_content='<p>وقوف المركبة في أماكن غير مخصصة للوقوف.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>ملاحقة مركبات الطوارئ أثناء استعمال المنبهات'),
#  Document(metadata={}, page_content='مركبات الطوارئ أثناء استعمال المنبهات الخاصة'),
#  Document(metadata={}, page_content='الطوارئ أثناء استعمال المنبهات الخاصة بها.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>وضع كتابة أو رسم أو ملصق أو أي بيان آخر على'),
#  Document(metadata={}, page_content='كتابة أو رسم أو ملصق أو أي بيان آخر على جسم'),
#  Document(metadata={}, page_content='أو رسم أو ملصق أو أي بيان آخر على جسم المركبة دون'),
#  Document(metadata={}, page_content='أو ملصق أو أي بيان آخر على جسم المركبة دون موافقة'),
#  Document(metadata={}, page_content='أو أي بيان آخر على جسم المركبة دون موافقة الجهات'),
#  Document(metadata={}, page_content='على جسم المركبة دون موافقة الجهات المختصة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 300 - 500 ريال</h1>'),
#  Document(metadata={}, page_content='<p>التباطؤ في السير على نحو يعرقل الحركة.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 500 - 900 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم إعطاء أفضلية المرور للمركبات القادمة من'),
#  Document(metadata={}, page_content='إعطاء أفضلية المرور للمركبات القادمة من طريق'),
#  Document(metadata={}, page_content='أفضلية المرور للمركبات القادمة من طريق رئيسي في'),
#  Document(metadata={}, page_content='المرور للمركبات القادمة من طريق رئيسي في حالة'),
#  Document(metadata={}, page_content='للمركبات القادمة من طريق رئيسي في حالة تقاطعها مع'),
#  Document(metadata={}, page_content='القادمة من طريق رئيسي في حالة تقاطعها مع طريق'),
#  Document(metadata={}, page_content='من طريق رئيسي في حالة تقاطعها مع طريق فرعي أو'),
#  Document(metadata={}, page_content='طريق رئيسي في حالة تقاطعها مع طريق فرعي أو طريق'),
#  Document(metadata={}, page_content='في حالة تقاطعها مع طريق فرعي أو طريق ترابي.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 1000 - 2000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>النزول أو الركوب أثناء سير المركبات.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 150 - 300 ريال</h1>'),
#  Document(metadata={}, page_content='<p>مخالفة قواعد استعمال أنوار التلاقي.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>تجاوز حافلات النقل المدرسي عند توقفها للتحميل'),
#  Document(metadata={}, page_content='حافلات النقل المدرسي عند توقفها للتحميل أو'),
#  Document(metadata={}, page_content='النقل المدرسي عند توقفها للتحميل أو التنزيل.</p>'),
#  Document(metadata={}, page_content='<h1>الغرامة المالية 3000 - 6000 ريال</h1>'),
#  Document(metadata={}, page_content='<p>عدم الوقوف عند مراكز الضبط الأمني أو نقاط'),
#  Document(metadata={}, page_content='الوقوف عند مراكز الضبط الأمني أو نقاط التفتيش أو'),
#  Document(metadata={}, page_content='عند مراكز الضبط الأمني أو نقاط التفتيش أو عدم'),
#  Document(metadata={}, page_content='مراكز الضبط الأمني أو نقاط التفتيش أو عدم الوقوف'),
#  Document(metadata={}, page_content='الأمني أو نقاط التفتيش أو عدم الوقوف للدورية'),
#  Document(metadata={}, page_content='أو نقاط التفتيش أو عدم الوقوف للدورية الأمنية عند'),
#  Document(metadata={}, page_content='التفتيش أو عدم الوقوف للدورية الأمنية عند وجود'),
#  Document(metadata={}, page_content='أو عدم الوقوف للدورية الأمنية عند وجود توجيه أو'),
#  Document(metadata={}, page_content='الوقوف للدورية الأمنية عند وجود توجيه أو علامة'),
#  Document(metadata={}, page_content='للدورية الأمنية عند وجود توجيه أو علامة توجب'),
#  Document(metadata={}, page_content='الأمنية عند وجود توجيه أو علامة توجب الوقوف.</p>')]

# %% [markdown]
# ## Step 5: Generate Embeddings for the Documents

# %% [markdown]
# Generate embeddings for the chunks of text using HuggingFace's pre-trained Arabic language model. These embeddings will be stored in a `Chroma` vector store.

# %%
embedding_function = SentenceTransformerEmbeddings(model_name="CAMeL-Lab/bert-base-arabic-camelbert-mix")
db = Chroma.from_documents(documents, embedding_function, persist_directory="./chroma_db")
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name CAMeL-Lab/bert-base-arabic-camelbert-mix. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/468 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/305k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# # Step 6: Define the RAG Prompt Template

# %% [markdown]
# Define a custom prompt template in Arabic to retrieve traffic violation-related answers based on the context. Ensure the template encourages the model to give **advice** in **Arabic**, staying within the context provided.

# %%
rag_prompt_template = """
السياق: {context}
السؤال: {query}
الإجابة:
يرجى تقديم اجابة تفصيلية باللغة العربيه فقط
"""

# %% [markdown]
# ## Step 7: Initialize the Language Model

# %% [markdown]
# Initialize the language model using the Groq API. Set up the model with a specific configuration, including the API key, temperature setting, and model name.

# %%
groq_api_key = "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"
llm = ChatGroq(temperature=0, groq_api_key=groq_api_key, model_name="llama3-8b-8192")

# %% [markdown]
# ## Step 8: Create the LLM Chain

# %% [markdown]
# Now, you will create an LLM Chain that combines the language model and the prompt template you defined. This chain will be used to generate responses based on the retrieved context.

# %%
prompt_template = PromptTemplate(
    template=rag_prompt_template, input_variables=["context", "query"]
)
llm_chain = LLMChain(llm=llm,
                 prompt=prompt_template,
                 )

# %%
prompt = PromptTemplate(template=rag_prompt_template, input_variables=["context", "query"])
llm_chain = LLMChain(llm=llm, prompt=prompt)

# %% [markdown]
# ## Step 9: Implement the Query Function

# %% [markdown]
# Create a function `query_rag` that will take a user query as input, retrieve relevant context from the vector store, and use the language model to generate a response based on that context.

# %%
def query_rag(user_query):
    relevant_context = db.similarity_search(user_query)
    context = "\n".join([doc.page_content for doc in relevant_context])
    response = llm_chain.run(context=context, query=user_query)

    return response

# %% [markdown]
# ## Step 10: Inference - Running Queries in the RAG System

# %% [markdown]
# In this final step, you will implement an inference pipeline to handle real-time queries. You will allow the system to retrieve the most relevant violations and fines based on a user's input and generate a response.
#
# 1. Inference Workflow:
#
#   * The user inputs a query (e.g., "ماهي الغرامة على القيادة بدون رخصة؟").
#   * The system searches for the most relevant context from the traffic violation vector store.
#   * It generates an answer and advice based on the context.
#
# 2. Goal:
#   * Run the inference to answer questions based on the traffic violation dataset.

# %%
def run_inference():
    response = query_rag("ماهي الغرامة على القيادة بدون رخصة في السعودية؟")
    print("إجابة: ", response)
run_inference()
# Out:
# إجابة:  في المملكة العربية السعودية، الغرامة على القيادة بدون رخصة قيادة هي 500 ريال سعودي، بالإضافة إلى سحب رخصة القيادة لمدة سنة واحدة، وفقاً لما جاء في المادة 48 من قانون المرور السعودي. كما أن المادة 49 من القانون نفسه توجب على من القيادة بدون رخصة أن يخضع لغرامة تتراوح بين 500 ريال سعودي إلى 1,000 ريال سعودي، بالإضافة إلى سحب رخصة القيادة لمدة سنة واحدة.
#
# كما أن هناك غرامات أخرى تتراوح بين 200 ريال سعودي إلى 500 ريال سعودي لمن القيادة بدون رخصة قيادة في حالات خاصة، مثل القيادة بدون رخصة قيادة لمدة قصيرة أو القيادة بدون رخصة قيادة في منطقة محددة.
#
# فيما يتعلق بالمرور للمشاة، فأن أفضلية المرور للمشاة أثناء عبورهم في المسارات هي أنهم يجب أن يأخذوا الممرات المخصصة لهم، وينتظروا حتى يأذن لهم المرور، وفقاً لما جاء في المادة 34 من قانون المرور السعودي.
#
# أما فيما يتعلق بالمرور للمركبات، فأن أفضلية المرور للمركبات القادمة من طريق رئيسي هي أنهم يجب أن يأخذوا الممرات المخصصة لهم، وينتظروا حتى يأذن لهم المرور، وفقاً لما جاء في المادة 35 من قانون المرور السعودي. كما أن أفضلية المرور للمركبات القادمة من الاتجاهات هي أنهم يجب أن يأخذوا الممرات المخصصة لهم، وينتظروا حتى يأذن لهم المرور، وفقاً لما جاء في المادة 36 من القانون نفسه.
#
# في النهاية، يجب أن نذكر أن الغرامة على القيادة بدون رخصة في السعودية هي 500 ريال سعودي، بالإضافة إلى سحب رخصة القيادة لمدة سنة واحدة، وفقاً لما جاء في المادة 48 من قانون المرور السعودي.

# %%
def run_inference():
    response = query_rag("كم اقصى سرعة مسموحة  في المسار الايسر؟")
    print("إجابة: ", response)
run_inference()
# Out:
# إجابة:  في حال تغيير اتجاه السائق بالدوران للخلف لإعطاء الأفضلية للمركبة القادمة من اليمين، يجب أن يتباطأ السائق لمنح المركبة القادمة من اليمين الأفضلية. في هذه الحالة، السائق يجب أن يتباطأ حتى يصبح المركبة القادمة من اليمين في مسار اليمين.
#
# فيما يتعلق بالسرعة المسموحة في المسار الايسر، يجب أن ننظر إلى المادة 34 من قانون المرور المصرى، التي تspecifies أن السرعة المسموحة في المسار الايسر هي 90 كيلومترا في الساعة.
#
# لذلك، الأقصى سرعة مسموحة في المسار الايسر هي 90 كيلومترا في الساعة.

# %%
def run_inference():
    response = query_rag("ماهي  مخالفة قطع الاشارة؟")
    print("إجابة: ", response)
run_inference()
# Out:
# إجابة:  مخالفة قطع الاشارة هي إحدى مخالفات المرور التي تتمثل في توقف المركبة أو مرورها على النقطة التي يوجد بها إشارة مرور دون أن يلتزم المرور بالتوقف أو المرور وفقاً لما يأمر به الإشارة. هذه المخالفة تتمثل في عدم احترام المرور للاشارة المرورية التي تمنع أو تطلب من المرور توقف أو مرور.
#
# في حالة عدم وجود إشارات ضوئية، يلزم المرور أن يلتزم بالتوقف أو المرور وفقاً لما يأمر به الإشارة المرورية الموجودة في المكان، مثل الإشارة اليدوية أو الإشارة باللغة.
#
# هذه المخالفة تتمثل في مخالفة قطع الاشارة، والتي تتمثل في توقف المركبة أو مرورها على النقطة التي يوجد بها إشارة مرور دون أن يلتزم المرور بالتوقف أو المرور وفقاً لما يأمر به الإشارة.
#
# هذه المخالفة تتمثل في مخالفة قطع الاشارة، والتي تتمثل في مخالفة احترام الإشارة المرورية، والتي تهدف إلى ضمان سلامة المرور والحركة المرورية.
