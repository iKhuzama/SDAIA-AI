# %% [markdown]
# #Import Required Libraries

# %%
# %pip install roboflow
# %pip install ultralytics
# %pip install ipython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.6/871.6 kB 3.8 MB/s eta 0:00:00
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...

# %%
#import tensorflow and keras
import tensorflow as tf
from keras import layers, models, datasets

from ultralytics import YOLO
import os
from IPython import display
from roboflow import Roboflow

# %% [markdown]
# #Data Collection

# %%
rf = Roboflow(api_key="6Mtasz76njBtqTQgOjjr")
project = rf.workspace("cardetetction").project("car-jgm0v")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.83, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Car-1 in yolov8:: 100%|██████████| 4812/4812 [00:01<00:00, 3220.81it/s]

# %% [markdown]
# #Data Preprocessing

# %%
display.clear_output()

# %% [markdown]
# #Model selection, implementation, training

# %%
# !yolo task =detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=25 imgsz=640 optimizer=Adam lr0=0.02
# Out:
# Ultralytics YOLOv8.2.83 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# #Model Testing

# %%
# !yolo task =detect mode=val model=/content/runs/detect/train2/weights/best.pt source={dataset.location}/test/images
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.2.83 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/content/datasets/coco8/images/val'
# ...
# 100% 433k/433k [00:00<00:00, 18.1MB/s]
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% 25/25 [00:00<00:00, 4655.37file/s]
# Dataset download success ✅ (0.6s), saved to /content/datasets
#
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 770.91it/s]
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0% 0/1 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
# ...

# %% [markdown]
# #Model Evaluation

# %%
# !yolo task =detect mode=predict model=/content/runs/detect/train2/weights/best.pt source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.2.83 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/150 /content/Car-1/test/images/adit_mp4-1186_jpg.rf.347b588766baec4ee6672242733afdef.jpg: 640x640 6 Trucks, 8 carss, 17.7ms
# image 2/150 /content/Car-1/test/images/adit_mp4-120_jpg.rf.eb0888df3f673c15e259c0640870874c.jpg: 640x640 1 Truck, 17 carss, 14.4ms
# image 3/150 /content/Car-1/test/images/adit_mp4-1237_jpg.rf.47f7198a2cde0e1e07c63df58fd4434b.jpg: 640x640 5 Trucks, 7 carss, 15.6ms
# image 4/150 /content/Car-1/test/images/adit_mp4-1374_jpg.rf.26dde8e1d3e3c470f23317a59b5ebb23.jpg: 640x640 2 Trucks, 8 carss, 10.1ms
# image 5/150 /content/Car-1/test/images/adit_mp4-1384_jpg.rf.be2cc8db69ef1e022f57e37533c9706a.jpg: 640x640 2 Trucks, 7 carss, 13.5ms
# image 6/150 /content/Car-1/test/images/adit_mp4-1385_jpg.rf.4eae798ad9b596650c7cdc8e78fc2518.jpg: 640x640 2 Trucks, 7 carss, 13.1ms
# ...
